# %%
import tkinter as tk
from tkinter import filedialog, messagebox, ttk
import cv2
import os
import shutil
import yaml
import json
from ultralytics import YOLO
from PIL import Image, ImageTk
import numpy as np
import threading
from tkinter import ttk

PROJECTS_DIR = os.path.join(os.getcwd(), "projects")
os.makedirs(PROJECTS_DIR, exist_ok=True)

# --- BoundingBoxEditor Class ---
class BoundingBoxEditor:
    def __init__(self, root, project):
        self.root = root
        self.model = None  # Initialize model to None.
        self.project = project
        self.root.title(f"Bounding Box Editor - Project: {project['project_name']}")
        # Use project settings for dataset folder; label folder is a subfolder named "labels".
        self.folder_path = project["dataset_path"]
        self.label_folder = os.path.join(self.folder_path, "labels")
        os.makedirs(self.label_folder, exist_ok=True)

        # YAML file handling (create a default one if missing)
        self.yaml_path = os.path.join(self.folder_path, "dataset.yaml")
        if not os.path.exists(self.yaml_path):
            default_yaml = {
                "train": f"'{os.path.join(self.folder_path, 'train')}'",
                "val": f"'{os.path.join(self.folder_path, 'val')}'",
                "nc": 1,  # Number of classes
                "names": ["person"]
            }
            with open(self.yaml_path, "w") as f:
                yaml.dump(default_yaml, f, sort_keys=False)
        with open(self.yaml_path, "r") as f:
            data = yaml.safe_load(f)
        # Read the class names from YAML (expected as an array)
        raw_names = data.get("names", ["person"])
        if isinstance(raw_names, dict):
            # Convert dict to list sorted by keys (assuming keys are integers as strings)
            self.class_names = [raw_names[k] for k in sorted(raw_names.keys(), key=lambda x: int(x))]
        else:
            self.class_names = raw_names
        self.paths = data.get("paths", {"dataset": self.folder_path, "train": "", "val": ""})
        self.validation = bool(self.paths.get("val"))
      
        # Initialize unique colors for each class.
        self.update_class_colors()
        # Dictionary to hold image statuses (e.g. "edited", "viewed", "not_viewed", "review_needed")
        self.image_status = {}

        # Create main frames.
        self.main_frame = tk.Frame(root)
        self.main_frame.pack(fill=tk.BOTH, expand=True)

        # Left frame: Treeview for image list.
        self.image_list_frame = tk.Frame(self.main_frame, width=200)
        self.image_list_frame.pack(side=tk.LEFT, fill=tk.Y)
        self.image_tree = ttk.Treeview(self.image_list_frame, columns=("filename",), show="headings", selectmode="browse")
        self.image_tree.heading("filename", text="Images")
        self.image_tree.column("filename", anchor=tk.W)
        self.image_tree.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
        self.image_tree.tag_configure("edited", background="lightgreen")
        self.image_tree.tag_configure("viewed", background="lightblue")
        self.image_tree.tag_configure("not_viewed", background="white")
        self.image_tree.tag_configure("review_needed", background="red")
        self.scrollbar = tk.Scrollbar(self.image_list_frame, orient="vertical", command=self.image_tree.yview)
        self.scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
        self.image_tree.configure(yscrollcommand=self.scrollbar.set)
        self.image_tree.bind("<<TreeviewSelect>>", self.on_image_select)

        # Center frame: Canvas and info panel.
        self.content_frame = tk.Frame(self.main_frame)
        self.content_frame.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
        self.canvas = tk.Canvas(self.content_frame, width=500, height=720)
        self.canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
        self.canvas.bind("<MouseWheel>", self.on_mouse_wheel)
        self.canvas.bind("<Button-4>", self.on_mouse_wheel)
        self.canvas.bind("<Button-5>", self.on_mouse_wheel)
        self.info_frame = tk.Frame(self.content_frame, width=300)
        self.info_frame.pack(side=tk.LEFT, fill=tk.Y)
        self.info_label = tk.Label(self.info_frame, text="Bounding Box Info", font=("Arial", 14))
        self.info_label.pack(pady=10)
        self.image_name_label = tk.Label(self.info_frame, text="", font=("Arial", 12))
        self.image_name_label.pack(pady=5)
        self.bbox_info_frame = tk.Frame(self.info_frame)
        self.bbox_info_frame.pack(pady=10, fill=tk.BOTH, expand=True)

        # Right frame: Class list and related buttons.
        self.class_frame = tk.Frame(self.content_frame, width=200)
        self.class_frame.pack(side=tk.RIGHT, fill=tk.Y)
        self.class_label = tk.Label(self.class_frame, text="Classes", font=("Arial", 14))
        self.class_label.pack(pady=10)
        self.class_listbox = tk.Listbox(self.class_frame)
        self.class_listbox.pack(pady=10, fill=tk.BOTH, expand=True)
        for cls in self.class_names:
            self.class_listbox.insert(tk.END, cls)
        self.class_entry = tk.Entry(self.class_frame)
        self.class_entry.pack(pady=5, fill=tk.X, padx=5)
      
        # Buttons to add, update, and remove classes.
        btn_frame = tk.Frame(self.class_frame)
        btn_frame.pack(pady=5)
        tk.Button(btn_frame, text="Add", command=self.add_class).pack(side=tk.LEFT, padx=2)
        tk.Button(btn_frame, text="Update", command=self.update_class).pack(side=tk.LEFT, padx=2)
        tk.Button(btn_frame, text="Remove", command=self.remove_class).pack(side=tk.LEFT, padx=2)
        self.clear_selection_button = tk.Button(self.class_frame, text="Clear Selection", command=self.clear_class_selection)
        self.clear_selection_button.pack(pady=10)
        self.paste_all_button = tk.Button(self.class_frame, text="Paste All", command=self.paste_all_bboxes)
        self.paste_all_button.pack(pady=10)
        self.delete_image_button = tk.Button(self.class_frame, text="Delete Image", command=self.delete_image)
        self.delete_image_button.pack(pady=10)
        self.copy_frame = tk.Frame(self.class_frame)
        self.copy_frame.pack(pady=10, fill=tk.BOTH, expand=True)
        self.copy_frame.bind("<MouseWheel>", self.on_mouse_wheel)
        self.copy_frame.bind("<Button-4>", self.on_mouse_wheel)
        self.copy_frame.bind("<Button-5>", self.on_mouse_wheel)
        self.copied_bbox_list = []
        self.update_copied_bbox_display()

        # Initialize image and bounding box variables.
        self.image = None
        self.image_path = None
        self.bboxes = []
        self.current_bbox = None
        self.rect = None
        self.image_files = []
        self.current_image_index = -1
        self.selected_class_index = None

        # Top-level buttons.
        self.auto_annotate_button = tk.Button(root, text="Auto Annotate", command=self.auto_annotate_dataset_threaded)
        self.auto_annotate_button.pack(side=tk.LEFT)
        self.save_button = tk.Button(root, text="Save Labels", command=self.save_labels)
        self.save_button.pack(side=tk.LEFT)
        self.load_model_button = tk.Button(root, text="Load Model", command=self.load_model)
        self.load_model_button.pack(side=tk.LEFT)
        self.export_yaml_button = tk.Button(root, text="Export YAML", command=self.export_yaml_window)
        self.export_yaml_button.pack(side=tk.LEFT)

        # Bind events for drawing and navigation.
        self.canvas.bind("<Button-1>", self.on_click)
        self.canvas.bind("<B1-Motion>", self.on_drag)
        self.canvas.bind("<ButtonRelease-1>", self.on_release)
        self.root.bind("<Control-s>", lambda event: self.save_labels())

        self.root.bind("<Escape>", lambda event: self.clear_class_selection())
        self.root.bind("<Down>", self.next_image)
        self.root.bind("<Up>", self.previous_image)
        self.class_listbox.bind("<Down>", lambda e: "break")
        self.class_listbox.bind("<Up>", lambda e: "break")
        self.root.bind("<Key>", self.on_key_press)
      
        # Load dataset images and statuses.
        self.load_dataset()

    def update_yaml_classes(self):
        """Update the YAML file 'nc' and 'names' fields with the current list of classes."""
        try:
            with open(self.yaml_path, "r") as f:
                data = yaml.safe_load(f)
        except Exception as e:
            data = {}
        data["nc"] = len(self.class_names)
        data["names"] = self.class_names  # stored as a YAML list (array)
        # Update dataset paths as raw strings.
        data["train"] = f"'{os.path.join(self.folder_path, 'train')}'"
        data["val"] = f"'{os.path.join(self.folder_path, 'val')}'"
        with open(self.yaml_path, "w") as f:
            yaml.dump(data, f, sort_keys=False)

    def add_class(self):
        new_class = self.class_entry.get().strip()
        if new_class:
            self.class_listbox.insert(tk.END, new_class)
            self.class_names.append(new_class)
            self.update_class_colors()  # Refresh the color mapping.
            self.update_yaml_classes()  # Update YAML file.
            self.class_entry.delete(0, tk.END)

    def update_class(self):
        selection = self.class_listbox.curselection()
        if selection:
            index = selection[0]
            new_val = self.class_entry.get().strip()
            if new_val:
                self.class_listbox.delete(index)
                self.class_listbox.insert(index, new_val)
                self.class_names[index] = new_val
                self.update_class_colors()  # Update color mapping.
                self.update_yaml_classes()  # Update YAML file.
                self.class_entry.delete(0, tk.END)

    def remove_class(self):
        selection = self.class_listbox.curselection()
        if selection:
            if len(self.class_names) == 1:
                messagebox.showwarning("Warning", "You must have at least one class.")
                return
            index = selection[0]
            self.class_listbox.delete(index)
            self.class_names.pop(index)
            self.update_class_colors()
            self.update_yaml_classes()
            updated_bboxes = []
            for bbox in self.bboxes:
                x, y, w, h, class_id = bbox
                if class_id >= len(self.class_names):
                    class_id = 0
                updated_bboxes.append((x, y, w, h, class_id))
            self.bboxes = updated_bboxes
            self.display_bboxes()

    def update_class_colors(self):
        predefined_colors = ["red", "green", "blue", "yellow", "cyan", "magenta", "orange", "purple", "brown", "pink"]
        self.class_colors = {i: predefined_colors[i % len(predefined_colors)] for i in range(len(self.class_names))}

    def on_key_press(self, event):
        if event.char.isdigit():
            idx = int(event.char) - 1
            if 0 <= idx < len(self.class_names):
                self.class_listbox.selection_clear(0, tk.END)
                self.class_listbox.selection_set(idx)
                self.selected_class_index = idx

    def load_model(self):
        model_path = filedialog.askopenfilename(title="Select YOLO Model", filetypes=[("PyTorch Model", "*.pt"), ("All Files", "*.*")])
        if model_path:
            try:
                self.model = YOLO(model_path)
                messagebox.showinfo("Success", f"Model loaded successfully from {model_path}")
            except Exception as e:
                messagebox.showerror("Error", f"Failed to load model:\n{e}")

    def update_copied_bbox_display(self):
        for widget in self.copy_frame.winfo_children():
            widget.destroy()
        if not self.copied_bbox_list:
            tk.Label(self.copy_frame, text="Copied Bounding Boxes: None", font=("Arial", 12)).pack(pady=10)
        else:
            for bbox in self.copied_bbox_list:
                x, y, w, h, class_id = bbox
                tk.Label(self.copy_frame,
                         text=f"Class {self.class_names[class_id]}, ({x}, {y}), ({w}, {h})",
                         font=("Arial", 12)).pack(pady=5)

    def update_class_listbox(self):
        self.class_listbox.delete(0, tk.END)
        for cls in self.class_names:
            self.class_listbox.insert(tk.END, cls)
        self.update_class_colors()

    # --- Methods to persist image statuses ---
    def save_statuses(self):
        if self.folder_path:
            status_file = os.path.join(self.folder_path, "image_status.json")
            with open(status_file, "w") as f:
                json.dump(self.image_status, f)

    def load_statuses(self):
        if self.folder_path:
            status_file = os.path.join(self.folder_path, "image_status.json")
            if os.path.exists(status_file):
                with open(status_file, "r") as f:
                    self.image_status = json.load(f)
            else:
                self.image_status = {}

    # --- Export YAML Window ---
    def export_yaml_window(self):
        export_win = tk.Toplevel(self.root)
        export_win.title("Export YAML Settings")
        export_win.transient(self.root)
        export_win.grab_set()
      
        # --- Export Destination Option ---
        export_to_current_var = tk.BooleanVar(value=True)
      
        def toggle_custom(*args):
            if export_to_current_var.get():
                custom_export_entry.config(state="disabled")
                custom_export_button.config(state="disabled")
            else:
                custom_export_entry.config(state="normal")
                custom_export_button.config(state="normal")
        export_to_current_var.trace("w", toggle_custom)
      
        current_frame = tk.Frame(export_win)
        current_frame.pack(fill=tk.X, padx=10, pady=5)
        tk.Checkbutton(
            current_frame,
            text="Export to Current Dataset Location",
            variable=export_to_current_var
        ).pack(side=tk.LEFT)
      
        custom_frame = tk.Frame(export_win)
        custom_frame.pack(fill=tk.X, padx=10, pady=5)
        tk.Label(custom_frame, text="Custom Export Location:").pack(side=tk.LEFT)
        custom_export_entry = tk.Entry(custom_frame, width=40)
        custom_export_entry.pack(side=tk.LEFT, padx=5)
        custom_export_button = tk.Button(
            custom_frame, 
            text="Browse", 
            command=lambda: custom_export_entry.insert(0, filedialog.askdirectory(title="Select Export Folder") or "")
        )
        custom_export_button.pack(side=tk.LEFT)
        custom_export_entry.config(state="disabled")
        custom_export_button.config(state="disabled")
      
        # --- Split Option ---
        split_option = tk.StringVar(value="in_sample")  # "in_sample" or "split"
        split_frame = tk.Frame(export_win)
        split_frame.pack(fill=tk.X, padx=10, pady=5)
        tk.Label(split_frame, text="Validation Mode:").pack(side=tk.LEFT)
        tk.Radiobutton(split_frame, text="In-Sample Validation", variable=split_option, value="in_sample").pack(side=tk.LEFT, padx=5)
        tk.Radiobutton(split_frame, text="Split Data", variable=split_option, value="split").pack(side=tk.LEFT, padx=5)
      
        # --- Test Data Option (active only when Split Data is selected) ---
        test_data_var = tk.BooleanVar(value=False)  # False => 8:2, True => 6:2:2
        def toggle_test_data(*args):
            if split_option.get() == "split":
                test_data_check.config(state="normal")
            else:
                test_data_check.config(state="disabled")
        split_option.trace("w", toggle_test_data)
      
        test_data_frame = tk.Frame(export_win)
        test_data_frame.pack(fill=tk.X, padx=10, pady=5)
        test_data_check = tk.Checkbutton(test_data_frame, text="Include Test Data (6:2:2)", variable=test_data_var)
        test_data_check.pack(side=tk.LEFT)
        test_data_check.config(state="disabled")
      
        # --- Validation Option (for YAML export) ---
        include_val_var = tk.BooleanVar(value=self.validation)
        val_frame = tk.Frame(export_win)
        val_frame.pack(fill=tk.X, padx=10, pady=5)
        tk.Checkbutton(
            val_frame,
            text="Include Validation in YAML",
            variable=include_val_var
        ).pack(side=tk.LEFT)
      
        # --- Export Button(s) ---
        button_frame = tk.Frame(export_win)
        button_frame.pack(fill=tk.X, padx=10, pady=10)
      
        def export_yaml():
            try:
                with open(self.yaml_path, "r") as f:
                    data = yaml.safe_load(f)
            except Exception as e:
                messagebox.showerror("Error", f"Could not load YAML file:\n{e}")
                return
          
            if not include_val_var.get():
                data["val"] = ""
          
            if export_to_current_var.get():
                base_export_folder = self.folder_path
            else:
                base_export_folder = custom_export_entry.get().strip()
                if not base_export_folder:
                    messagebox.showerror("Error", "Please select a custom export location.")
                    return
          
            export_folder = os.path.join(base_export_folder, "exported")
            os.makedirs(export_folder, exist_ok=True)
          
            if split_option.get() == "in_sample":
                train_folder = os.path.join(export_folder, "train")
                os.makedirs(os.path.join(train_folder, "images"), exist_ok=True)
                os.makedirs(os.path.join(train_folder, "labels"), exist_ok=True)
                val_folder = train_folder  # In-sample: use same folder for val.
                data["train"] = f"{train_folder}"
                data["val"] = f"{val_folder}"
            else:
                annotated = []
                for image_file in self.image_files:
                    label_file = os.path.splitext(image_file)[0] + '.txt'
                    src_label_path = os.path.join(self.label_folder, label_file)
                    if os.path.exists(src_label_path) and os.path.getsize(src_label_path) > 0:
                        annotated.append(image_file)
                num = len(annotated)
                if num == 0:
                    messagebox.showwarning("Warning", "No annotated images found for export.")
                    return
                if test_data_var.get():
                    num_train = int(num * 0.6)
                    num_val = int(num * 0.2)
                    num_test = num - num_train - num_val
                    train_files = annotated[:num_train]
                    val_files = annotated[num_train:num_train+num_val]
                    test_files = annotated[num_train+num_val:]
                    test_folder = os.path.join(export_folder, "test")
                    os.makedirs(os.path.join(test_folder, "images"), exist_ok=True)
                    os.makedirs(os.path.join(test_folder, "labels"), exist_ok=True)
                    data["test"] = f"{test_folder}"
                else:
                    num_train = int(num * 0.8)
                    train_files = annotated[:num_train]
                    val_files = annotated[num_train:]
                    test_files = []
                    data["test"] = ""
              
                train_folder = os.path.join(export_folder, "train")
                os.makedirs(os.path.join(train_folder, "images"), exist_ok=True)
                os.makedirs(os.path.join(train_folder, "labels"), exist_ok=True)
                val_folder = os.path.join(export_folder, "val")
                os.makedirs(os.path.join(val_folder, "images"), exist_ok=True)
                os.makedirs(os.path.join(val_folder, "labels"), exist_ok=True)
                data["train"] = f"{train_folder}"
                data["val"] = f"{val_folder}"
          
            export_yaml_path = os.path.join(export_folder, "dataset.yaml")
            try:
                with open(export_yaml_path, "w") as f:
                    yaml.dump(data, f, sort_keys=False)
            except Exception as e:
                messagebox.showerror("Error", f"Could not export YAML:\n{e}")
                return
          
            def copy_files(file_list, images_dst, labels_dst):
                for image_file in file_list:
                    label_file = os.path.splitext(image_file)[0] + '.txt'
                    src_image_path = os.path.join(self.folder_path, image_file)
                    src_label_path = os.path.join(self.label_folder, label_file)
                    try:
                        shutil.copy(src_image_path, os.path.join(images_dst, image_file))
                        shutil.copy(src_label_path, os.path.join(labels_dst, label_file))
                    except Exception as e:
                        messagebox.showerror("Error", f"Failed to export {image_file}:\n{e}")
          
            if split_option.get() == "in_sample":
                all_files = [f for f in self.image_files 
                             if os.path.exists(os.path.join(self.label_folder, os.path.splitext(f)[0] + '.txt')) 
                             and os.path.getsize(os.path.join(self.label_folder, os.path.splitext(f)[0] + '.txt')) > 0]
                copy_files(all_files, os.path.join(train_folder, "images"), os.path.join(train_folder, "labels"))
            else:
                copy_files(train_files, os.path.join(train_folder, "images"), os.path.join(train_folder, "labels"))
                copy_files(val_files, os.path.join(val_folder, "images"), os.path.join(val_folder, "labels"))
                if test_files:
                    test_folder = os.path.join(export_folder, "test")
                    copy_files(test_files, os.path.join(test_folder, "images"), os.path.join(test_folder, "labels"))
          
            messagebox.showinfo("Success", f"Export complete!\nYAML and annotated images exported to:\n{export_folder}")
            export_win.destroy()
      
        tk.Button(button_frame, text="Export", command=export_yaml).pack(side=tk.RIGHT, padx=5)
        tk.Button(button_frame, text="Cancel", command=export_win.destroy).pack(side=tk.RIGHT, padx=5)

    def load_dataset(self):
        if not self.folder_path:
            messagebox.showerror("Error", "Dataset folder not set.")
            return
        for item in self.image_tree.get_children():
            self.image_tree.delete(item)
        self.image_files = [f for f in os.listdir(self.folder_path)
                            if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
        if not self.image_files:
            messagebox.showinfo("No Images", "No images found in the selected folder.")
            return
        self.load_statuses()
        for image_file in self.image_files:
            status = self.image_status.get(image_file, "not_viewed")
            self.image_tree.insert("", tk.END, iid=image_file, values=(image_file,), tags=(status,))
        self.image_tree.tag_configure("review_needed", background="red")
        self.image_tree.tag_configure("edited", background="lightgreen")
        self.image_tree.tag_configure("viewed", background="lightblue")
        self.image_tree.tag_configure("not_viewed", background="white")
        self.save_statuses()

    # In the BoundingBoxEditor class, modify the auto_annotate_dataset_threaded method:

    def auto_annotate_dataset_threaded(self):
        self.auto_annotate_button.config(state=tk.DISABLED)
        # Create progress window without window controls
        self.progress_win = tk.Toplevel(self.root)
        self.progress_win.title("Auto Annotation Progress")
        
        # Remove window decorations and force focus
        self.progress_win.overrideredirect(True)
        self.progress_win.attributes("-topmost", True)
        
        # Create progress bar and label
        self.progress_var = tk.DoubleVar()
        self.progress_bar = ttk.Progressbar(self.progress_win, variable=self.progress_var, maximum=100)
        self.progress_bar.pack(padx=20, pady=10)
        self.progress_label = tk.Label(self.progress_win, text="0/0 images processed")
        self.progress_label.pack(pady=5)
        
        # Center the progress window over main application
        self.progress_win.update_idletasks()  # Needed to get proper window size
        main_width = self.root.winfo_width()
        main_height = self.root.winfo_height()
        main_x = self.root.winfo_x()
        main_y = self.root.winfo_y()
        
        progress_width = 300  # Fixed width for better control
        progress_height = 100
        
        x = main_x + (main_width - progress_width) // 2
        y = main_y + (main_height - progress_height) // 2
        
        self.progress_win.geometry(f"{progress_width}x{progress_height}+{x}+{y}")
        
        threading.Thread(target=self.auto_annotate_dataset, daemon=True).start()


    def update_progress(self, percent, current, total):
        self.progress_var.set(percent)
        self.progress_label.config(text=f"{current}/{total} images processed")
        
    def auto_annotate_dataset(self):
        if self.model is None:
            self.root.after(0, lambda: messagebox.showerror("Model Not Loaded", "Please load a YOLO model first."))
            return
        if not self.folder_path:
            self.root.after(0, lambda: messagebox.showerror("Dataset Not Loaded", "Please load a dataset first."))
            return
  
        threshold = 0.8
        flagged_images = []
        total_images = len(self.image_files)
  
        # Loop over images; update progress after each one.
        for idx, image_file in enumerate(self.image_files):
            image_path = os.path.join(self.folder_path, image_file)
            label_filename = os.path.splitext(image_file)[0] + '.txt'
            label_path = os.path.join(self.label_folder, label_filename)
              
            results = self.model(image_path, conf=0.5)
            bboxes = []
            uncertain = False
            current_count = idx + 1
            progress_percent = (current_count / total_images) * 100
            self.root.after(0, self.update_progress, progress_percent, current_count, total_images)

            
            for box in results[0].boxes:
                conf_score = box.conf[0].item() if hasattr(box, "conf") else 1.0
                # print(f"Detected confidence: {conf_score:.2f}")  # Debug print
                class_id = int(box.cls[0])
                if class_id >= len(self.class_names):
                    continue
                x_center, y_center, width, height = box.xywhn[0].cpu().numpy()
                orig_img = cv2.imread(image_path)
                img_h, img_w = orig_img.shape[:2]
                x_center_abs = x_center * img_w
                y_center_abs = y_center * img_h
                width_abs = width * img_w
                height_abs = height * img_h
                x_min = int(x_center_abs - width_abs / 2)
                y_min = int(y_center_abs - height_abs / 2)
                bboxes.append((x_min, y_min, int(width_abs), int(height_abs), class_id, conf_score))
      
                if conf_score < threshold:
                    uncertain = True
      
            if bboxes:
                if uncertain:
                    flagged_images.append(image_file)
                    self.image_status[image_file] = "review_needed"
                else:
                    with open(label_path, 'w') as label_file:
                        for bbox in bboxes:
                            x, y, w, h, class_id, conf = bbox
                            x_center = (x + w / 2) / img_w
                            y_center = (y + h / 2) / img_h
                            width_norm = w / img_w
                            height_norm = h / img_h
                            label_file.write(f"{class_id} {x_center} {y_center} {width_norm} {height_norm}\n")
                    self.image_status[image_file] = "edited"
            else:
                self.image_status[image_file] = "viewed"
          
            # Update progress bar in the main thread.
            progress_percent = ((idx + 1) / total_images) * 100
            self.root.after(0, lambda p=progress_percent: self.progress_var.set(p))
      
        self.save_statuses()
        self.root.after(0, self.progress_win.destroy)
        for image_file in self.image_files:
            self.image_tree.item(image_file, tags=(self.image_status.get(image_file, "not_viewed"),))
      
        if flagged_images:
            self.root.after(0, lambda: messagebox.showwarning("Active Learning", f"{len(flagged_images)} images have low-confidence detections and need review."))
        else:
            self.root.after(0, lambda: messagebox.showinfo("Auto Annotate", "Auto annotation completed with high confidence on all images."))
      
        # Re-enable the auto annotate button
        self.root.after(0, lambda: self.auto_annotate_button.config(state=tk.NORMAL))

    def run_inference_and_save_labels(self, image_path, label_path):
        if self.model is None:
            messagebox.showerror("Model Not Loaded", "Please load a YOLO model first.")
            return
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = self.model(image_path, conf=0.5)
        bboxes = []
        for box in results[0].boxes:
            class_id = int(box.cls[0])
            if class_id >= len(self.class_names):
                continue
            x_center, y_center, width, height = box.xywhn[0].cpu().numpy()
            img_h, img_w = image.shape[:2]
            x_center_abs = x_center * img_w
            y_center_abs = y_center * img_h
            width_abs = width * img_w
            height_abs = height * img_h
            x_min = int(x_center_abs - width_abs / 2)
            y_min = int(y_center_abs - height_abs / 2)
            bboxes.append((x_min, y_min, int(width_abs), int(height_abs), class_id))
        with open(label_path, 'w') as label_file:
            for bbox in bboxes:
                x, y, w, h, class_id = bbox
                img_h, img_w = image.shape[:2]
                x_center = (x + w/2) / img_w
                y_center = (y + h/2) / img_h
                width = w / img_w
                height = h / img_h
                label_file.write(f"{class_id} {x_center} {y_center} {width} {height}\n")

    def on_image_select(self, event):
        selected = self.image_tree.selection()
        if selected:
            image_file = selected[0]
            image_path = os.path.join(self.folder_path, image_file)
            self.load_image(image_path)

    def load_image(self, image_path=None):
        if image_path:
            self.image_path = image_path
            self.current_image_index = self.image_files.index(os.path.basename(image_path))
        else:
            self.image_path = filedialog.askopenfilename(filetypes=[("Image files", "*.jpg *.png *.jpeg")])
            if not self.image_path:
                return
            self.current_image_index = self.image_files.index(os.path.basename(self.image_path))
        self.image = cv2.imread(self.image_path)
        self.image = cv2.cvtColor(self.image, cv2.COLOR_BGR2RGB)
        self.image = cv2.resize(self.image, (500, 720))
        self.display_image()
        label_filename = os.path.splitext(os.path.basename(self.image_path))[0] + '.txt'
        label_path = os.path.join(self.label_folder, label_filename)
        self.bboxes = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as label_file:
                for line in label_file:
                    class_id, x_center, y_center, width, height = map(float, line.strip().split())
                    img_h, img_w = self.image.shape[:2]
                    x_center_abs = x_center * img_w
                    y_center_abs = y_center * img_h
                    width_abs = width * img_w
                    height_abs = height * img_h
                    x_min = int(x_center_abs - width_abs / 2)
                    y_min = int(y_center_abs - height_abs / 2)
                    self.bboxes.append((x_min, y_min, int(width_abs), int(height_abs), int(class_id)))
        self.display_bboxes()
        current_item_id = os.path.basename(self.image_path)
        new_status = "edited" if self.bboxes else "viewed"
        self.image_status[current_item_id] = new_status
        self.image_tree.item(current_item_id, tags=(new_status,))
        self.save_statuses()
        self.image_name_label.config(text=current_item_id)
        if self.selected_class_index is not None:
            self.class_listbox.selection_set(self.selected_class_index)

    def display_image(self):
        self.canvas.delete("all")
        self.tk_image = ImageTk.PhotoImage(image=Image.fromarray(self.image))
        self.canvas.create_image(0, 0, anchor=tk.NW, image=self.tk_image)

    def display_bboxes(self):
        self.canvas.delete("bbox")
        for widget in self.bbox_info_frame.winfo_children():
            widget.destroy()
        for i, bbox in enumerate(self.bboxes):
            x, y, w, h, class_id = bbox
            color = self.class_colors.get(class_id, "red")
            self.canvas.create_rectangle(x, y, x+w, y+h, outline=color, width=2, tags="bbox")
            self.canvas.create_text(x, y-10, text=self.class_names[class_id], fill=color, anchor=tk.NW, tags="bbox")
            bbox_info = tk.Frame(self.bbox_info_frame)
            bbox_info.pack(fill=tk.X, pady=2)
            tk.Label(bbox_info, text=f"Class: {self.class_names[class_id]}, Position: ({x}, {y}), Size: ({w}, {h})").pack(side=tk.LEFT)
            tk.Button(bbox_info, text="Copy", command=lambda bbox=bbox: self.copy_bbox(bbox)).pack(side=tk.RIGHT)
            tk.Button(bbox_info, text="Delete", command=lambda i=i: self.delete_bbox(i)).pack(side=tk.RIGHT)

    def copy_bbox(self, bbox):
        self.copied_bbox_list.append(bbox)
        self.update_copied_bbox_display()

    def paste_all_bboxes(self):
        if self.copied_bbox_list:
            for bbox in self.copied_bbox_list:
                self.bboxes.append(bbox)
            self.display_bboxes()
        else:
            messagebox.showinfo("Info", "No bounding boxes copied to paste.")

    def on_click(self, event):
        self.current_bbox = [event.x, event.y, event.x, event.y]
        self.rect = self.canvas.create_rectangle(event.x, event.y, event.x, event.y, outline="blue", width=2, tags="bbox")

    def on_drag(self, event):
        if self.current_bbox is not None:
            self.current_bbox[2] = event.x
            self.current_bbox[3] = event.y
            self.canvas.coords(self.rect, *self.current_bbox)

    def on_release(self, event):
        if self.image is None:
            # Optionally, show an error message or simply return
            messagebox.showwarning("No Image", "Please select or load an image first.")
            return
  
        x1, y1, x2, y2 = self.current_bbox
        # Constrain coordinates to image boundaries.
        img_h, img_w = self.image.shape[:2]
        x1 = max(0, min(x1, img_w))
        x2 = max(0, min(x2, img_w))
        y1 = max(0, min(y1, img_h))
        y2 = max(0, min(y2, img_h))
        x_min, y_min = min(x1, x2), min(y1, y2)
        width, height = abs(x2 - x1), abs(y2 - y1)
        selected_class_index = self.class_listbox.curselection()
        class_id = selected_class_index[0] if selected_class_index else 0
        self.bboxes.append((x_min, y_min, width, height, class_id))
        self.current_bbox = None
        self.rect = None
        self.display_bboxes()

    def delete_bbox(self, index):
        del self.bboxes[index]
        self.display_bboxes()

    def save_labels(self):
        if not self.image_path:
            return
        label_filename = os.path.splitext(os.path.basename(self.image_path))[0] + '.txt'
        label_path = os.path.join(self.label_folder, label_filename)
        with open(label_path, 'w') as label_file:
            for bbox in self.bboxes:
                x, y, w, h, class_id = bbox
                img_h, img_w = self.image.shape[:2]
                x_center = (x + w/2) / img_w
                y_center = (y + h/2) / img_h
                width = w / img_w
                height = h / img_h
                label_file.write(f"{class_id} {x_center} {y_center} {width} {height}\n")
        print(f"Saved labels for {self.image_path}")
        current_item_id = os.path.basename(self.image_path)
        new_status = "edited" if self.bboxes else "viewed"
        self.image_status[current_item_id] = new_status
        self.image_tree.item(current_item_id, tags=(new_status,))
        self.save_statuses()

    def next_image(self, event):
        self.root.focus_set()
        if self.current_image_index < len(self.image_files) - 1:
            self.current_image_index += 1
            self.load_image(os.path.join(self.folder_path, self.image_files[self.current_image_index]))

    def previous_image(self, event):
        self.root.focus_set()
        if self.current_image_index > 0:
            self.current_image_index -= 1
            self.load_image(os.path.join(self.folder_path, self.image_files[self.current_image_index]))

    def clear_class_selection(self):
        self.class_listbox.selection_clear(0, tk.END)
        self.selected_class_index = None
        self.copied_bbox_list = []
        self.update_copied_bbox_display()
        self.root.focus_set()

    def delete_image(self):
        if self.current_image_index == -1:
            messagebox.showwarning("Warning", "No image selected to delete.")
            return
        current_image_filename = self.image_files[self.current_image_index]
        image_path = os.path.join(self.folder_path, current_image_filename)
        label_filename = os.path.splitext(current_image_filename)[0] + '.txt'
        label_path = os.path.join(self.label_folder, label_filename)
        if not messagebox.askyesno("Confirm Delete", f"Delete {current_image_filename} and its label?"):
            return
        try:
            os.remove(image_path)
            if os.path.exists(label_path):
                os.remove(label_path)
        except Exception as e:
            messagebox.showerror("Error", f"Error deleting files: {e}")
            return
        del self.image_files[self.current_image_index]
        self.image_tree.delete(current_image_filename)
        self.canvas.delete("all")
        self.image_name_label.config(text="")
        self.bbox_info_frame.destroy()
        self.bbox_info_frame = tk.Frame(self.info_frame)
        self.bbox_info_frame.pack(pady=10, fill=tk.BOTH, expand=True)
        if self.image_files:
            self.current_image_index = min(self.current_image_index, len(self.image_files)-1)
            self.load_image(os.path.join(self.folder_path, self.image_files[self.current_image_index]))
        else:
            self.current_image_index = -1

    def on_mouse_wheel(self, event):
        if event.delta:
            if event.delta > 0:
                self.previous_image(event)
            else:
                self.next_image(event)
        elif event.num == 5:
            self.next_image(event)
        elif event.num == 4:
            self.previous_image(event)


def center_window(win, width, height):
    win.update_idletasks()
    screen_width = win.winfo_screenwidth()
    screen_height = win.winfo_screenheight()
    x = (screen_width - width) // 2
    y = (screen_height - height) // 2
    win.geometry(f"{width}x{height}+{x}+{y}")


class ProjectManager:
    def __init__(self, root):
        self.root = root
        self.root.title("Project Manager")
        center_window(self.root, 300, 200)
        self.main_frame = tk.Frame(root)
        self.main_frame.pack(fill=tk.BOTH, expand=True)
        tk.Label(self.main_frame, text="Select an option:", font=("Arial", 14)).pack(pady=10)
        tk.Button(self.main_frame, text="New Project", command=self.new_project).pack(pady=5)
        tk.Button(self.main_frame, text="Open Project", command=self.open_project).pack(pady=5)
        tk.Button(self.main_frame, text="Quit", command=root.quit).pack(pady=5)

    def new_project(self):
        new_win = tk.Toplevel(self.root)
        new_win.transient(self.root)
        new_win.grab_set()
        new_win.title("New Project")
        tk.Label(new_win, text="Project Name:").grid(row=0, column=0, padx=5, pady=5)
        name_entry = tk.Entry(new_win)
        name_entry.grid(row=0, column=1, padx=5, pady=5)
        tk.Label(new_win, text="Dataset Path:").grid(row=1, column=0, padx=5, pady=5)
        dataset_entry = tk.Entry(new_win, width=50)
        dataset_entry.grid(row=1, column=1, padx=5, pady=5)
        def browse_dataset():
            folder = filedialog.askdirectory(title="Select Dataset Folder")
            if folder:
                dataset_entry.delete(0, tk.END)
                dataset_entry.insert(0, folder)
        tk.Button(new_win, text="Browse", command=browse_dataset).grid(row=1, column=2, padx=5, pady=5)
        def create_project():
            project_name = name_entry.get().strip()
            dataset_path = dataset_entry.get().strip()
            if not project_name or not dataset_path:
                messagebox.showerror("Error", "Project name and dataset path are required.")
                return
            project = {
                "project_name": project_name,
                "dataset_path": dataset_path,
                "label_path": os.path.join(dataset_path, "labels")
            }
            project_file = os.path.join(PROJECTS_DIR, f"{project_name}.json")
            with open(project_file, "w") as f:
                json.dump(project, f)
            messagebox.showinfo("Project Created", f"Project '{project_name}' created successfully.")
            new_win.destroy()
            self.root.destroy()
            self.open_editor(project)
        tk.Button(new_win, text="Create Project", command=create_project).grid(row=2, column=1, pady=10)
        new_win.update_idletasks()
        req_width = new_win.winfo_reqwidth()
        req_height = new_win.winfo_reqheight()
        self.root.update_idletasks()
        parent_x = self.root.winfo_x()
        parent_y = self.root.winfo_y()
        parent_width = self.root.winfo_width()
        parent_height = self.root.winfo_height()
        pos_x = parent_x + (parent_width - req_width) // 2
        pos_y = parent_y + (parent_height - req_height) // 2
        new_win.geometry(f"{req_width}x{req_height}+{pos_x}+{pos_y}")

    def open_project(self):
        project_files = [f for f in os.listdir(PROJECTS_DIR) if f.endswith(".json")]
        if not project_files:
            messagebox.showinfo("No Projects", "No project files found in the projects folder.")
            return
        open_win = tk.Toplevel(self.root)
        open_win.transient(self.root)
        open_win.grab_set()
        open_win.title("Select a Project")
        tk.Label(open_win, text="Select a Project:", font=("Arial", 14)).pack(pady=10)
        listbox = tk.Listbox(open_win, width=50, height=10)
        listbox.pack(padx=10, pady=10)
        for f in project_files:
            listbox.insert(tk.END, f)
        tk.Button(open_win, text="Open", command=lambda: self.load_selected_project(listbox, open_win)).pack(pady=5)
        open_win.update_idletasks()
        req_width = open_win.winfo_reqwidth()
        req_height = open_win.winfo_reqheight()
        self.root.update_idletasks()
        parent_x = self.root.winfo_x()
        parent_y = self.root.winfo_y()
        parent_width = self.root.winfo_width()
        parent_height = self.root.winfo_height()
        pos_x = parent_x + (parent_width - req_width) // 2
        pos_y = parent_y + (parent_height - req_height) // 2
        open_win.geometry(f"{req_width}x{req_height}+{pos_x}+{pos_y}")

    def load_selected_project(self, listbox, open_win):
        selection = listbox.curselection()
        if selection:
            project_file = listbox.get(selection[0])
            full_path = os.path.join(PROJECTS_DIR, project_file)
            with open(full_path, "r") as f:
                project = json.load(f)
            open_win.destroy()
            self.root.destroy()
            self.open_editor(project)

    def open_editor(self, project):
        editor_root = tk.Tk()
        editor = BoundingBoxEditor(editor_root, project)
        editor_root.mainloop()

if __name__ == "__main__":
    root = tk.Tk()
    pm = ProjectManager(root)
    root.mainloop()
# Out:
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000000_resized (2).jpg: 640x640 (no detections), 50.6ms
# Speed: 32.8ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000000_resized.jpg: 640x640 (no detections), 10.1ms
# Speed: 3.2ms preprocess, 10.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000001_resized (2).jpg: 640x640 (no detections), 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000001_resized (3).jpg: 640x640 1 black_pawn, 11.6ms
# Speed: 3.4ms preprocess, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.88
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000001_resized (4).jpg: 640x640 (no detections), 13.0ms
# Speed: 3.8ms preprocess, 13.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000001_resized.jpg: 640x640 1 black_pawn, 12.9ms
# Speed: 3.9ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.84
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000002_resized (2).jpg: 640x640 1 black_pawn, 13.1ms
# Speed: 4.3ms preprocess, 13.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.57
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000002_resized (3).jpg: 640x640 1 black_pawn, 14.9ms
# Speed: 3.9ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.81
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000002_resized (4).jpg: 640x640 1 black_pawn, 12.5ms
# Speed: 3.9ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.79
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000002_resized.jpg: 640x640 1 black_pawn, 25.2ms
# Speed: 4.1ms preprocess, 25.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.91
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000003_resized (2).jpg: 640x640 1 black_pawn, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.62
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000003_resized (3).jpg: 640x640 1 black_pawn, 25.6ms
# Speed: 4.4ms preprocess, 25.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.90
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000003_resized (4).jpg: 640x640 (no detections), 13.5ms
# Speed: 4.1ms preprocess, 13.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000003_resized.jpg: 640x640 1 white_pawn, 12.2ms
# Speed: 3.9ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.76
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000004_resized (2).jpg: 640x640 (no detections), 18.3ms
# Speed: 3.9ms preprocess, 18.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000004_resized (3).jpg: 640x640 1 black_pawn, 12.1ms
# Speed: 4.2ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.86
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000004_resized (4).jpg: 640x640 1 black_pawn, 12.6ms
# Speed: 3.9ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.74
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000004_resized (5).jpg: 640x640 1 black_pawn, 15.8ms
# Speed: 3.9ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.86
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000004_resized.jpg: 640x640 1 white_pawn, 14.2ms
# Speed: 4.2ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.51
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000005_resized (2).jpg: 640x640 (no detections), 23.3ms
# Speed: 5.1ms preprocess, 23.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000005_resized (3).jpg: 640x640 (no detections), 17.1ms
# Speed: 4.5ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000005_resized (4).jpg: 640x640 (no detections), 16.7ms
# Speed: 4.4ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000005_resized (5).jpg: 640x640 (no detections), 15.0ms
# Speed: 4.7ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000005_resized.jpg: 640x640 1 black_pawn, 26.8ms
# Speed: 4.7ms preprocess, 26.8ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.77
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000006_resized (2).jpg: 640x640 (no detections), 22.8ms
# Speed: 4.5ms preprocess, 22.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000006_resized (3).jpg: 640x640 1 black_pawn, 28.7ms
# Speed: 6.5ms preprocess, 28.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.66
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000006_resized (4).jpg: 640x640 1 black_pawn, 16.4ms
# Speed: 5.3ms preprocess, 16.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.62
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000006_resized.jpg: 640x640 1 black_pawn, 15.6ms
# Speed: 4.7ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.77
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000007_resized (2).jpg: 640x640 (no detections), 19.1ms
# Speed: 5.0ms preprocess, 19.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000007_resized (3).jpg: 640x640 (no detections), 17.1ms
# Speed: 4.3ms preprocess, 17.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000007_resized (4).jpg: 640x640 (no detections), 15.4ms
# Speed: 4.7ms preprocess, 15.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000007_resized.jpg: 640x640 1 white_pawn, 1 black_pawn, 20.8ms
# Speed: 4.6ms preprocess, 20.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.90
# Detected confidence: 0.78
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000008_resized (2).jpg: 640x640 (no detections), 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000008_resized (3).jpg: 640x640 1 black_pawn, 23.3ms
# Speed: 4.4ms preprocess, 23.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.83
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000008_resized.jpg: 640x640 (no detections), 13.6ms
# Speed: 3.7ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000009_resized (2).jpg: 640x640 1 white_pawn, 14.0ms
# Speed: 4.4ms preprocess, 14.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.62
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000009_resized (3).jpg: 640x640 1 black_pawn, 18.5ms
# Speed: 3.8ms preprocess, 18.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.88
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000009_resized.jpg: 640x640 1 black_pawn, 27.6ms
# Speed: 4.3ms preprocess, 27.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.82
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000010_resized (2).jpg: 640x640 (no detections), 12.9ms
# Speed: 4.1ms preprocess, 12.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000010_resized (3).jpg: 640x640 1 black_pawn, 14.8ms
# Speed: 4.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.83
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000010_resized (4).jpg: 640x640 1 black_pawn, 15.1ms
# Speed: 6.5ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.69
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000010_resized (5).jpg: 640x640 1 black_pawn, 14.3ms
# Speed: 4.6ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.72
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000010_resized.jpg: 640x640 1 black_pawn, 25.6ms
# Speed: 4.9ms preprocess, 25.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.82
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000011_resized (2).jpg: 640x640 (no detections), 14.3ms
# Speed: 4.5ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000011_resized (3).jpg: 640x640 (no detections), 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000011_resized (4).jpg: 640x640 1 black_pawn, 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.73
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000011_resized.jpg: 640x640 1 black_pawn, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.94
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000012_resized (2).jpg: 640x640 1 black_pawn, 13.0ms
# Speed: 3.9ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.80
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000012_resized (3).jpg: 640x640 (no detections), 16.5ms
# Speed: 4.4ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000012_resized.jpg: 640x640 (no detections), 13.3ms
# Speed: 3.8ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000013_resized (2).jpg: 640x640 (no detections), 13.0ms
# Speed: 3.9ms preprocess, 13.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000013_resized (3).jpg: 640x640 (no detections), 13.2ms
# Speed: 4.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000013_resized (4).jpg: 640x640 (no detections), 13.8ms
# Speed: 4.3ms preprocess, 13.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000013_resized (5).jpg: 640x640 (no detections), 14.1ms
# Speed: 4.1ms preprocess, 14.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000013_resized.jpg: 640x640 1 black_pawn, 13.2ms
# Speed: 4.2ms preprocess, 13.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.69
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000014_resized (2).jpg: 640x640 (no detections), 15.8ms
# Speed: 4.1ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000014_resized (3).jpg: 640x640 (no detections), 13.4ms
# Speed: 4.0ms preprocess, 13.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000014_resized (4).jpg: 640x640 (no detections), 22.3ms
# Speed: 4.0ms preprocess, 22.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000014_resized (5).jpg: 640x640 (no detections), 13.2ms
# Speed: 3.8ms preprocess, 13.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000014_resized.jpg: 640x640 (no detections), 13.1ms
# Speed: 4.0ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000015_resized (2).jpg: 640x640 (no detections), 12.3ms
# Speed: 4.1ms preprocess, 12.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000015_resized (3).jpg: 640x640 (no detections), 17.2ms
# Speed: 3.8ms preprocess, 17.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000015_resized (4).jpg: 640x640 1 black_pawn, 13.8ms
# Speed: 3.6ms preprocess, 13.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.60
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000015_resized (5).jpg: 640x640 1 black_pawn, 25.2ms
# Speed: 3.9ms preprocess, 25.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.85
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000015_resized.jpg: 640x640 1 black_pawn, 17.4ms
# Speed: 3.7ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.80
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000016_resized (2).jpg: 640x640 (no detections), 14.1ms
# Speed: 4.1ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000016_resized (3).jpg: 640x640 (no detections), 30.4ms
# Speed: 4.7ms preprocess, 30.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000016_resized (4).jpg: 640x640 (no detections), 13.4ms
# Speed: 4.0ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000016_resized.jpg: 640x640 (no detections), 14.1ms
# Speed: 4.4ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000017_resized (2).jpg: 640x640 (no detections), 15.8ms
# Speed: 4.5ms preprocess, 15.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000017_resized (3).jpg: 640x640 (no detections), 15.6ms
# Speed: 4.7ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000017_resized (4).jpg: 640x640 1 black_pawn, 15.2ms
# Speed: 4.4ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.51
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000017_resized.jpg: 640x640 1 black_pawn, 14.3ms
# Speed: 4.8ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.52
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000018_resized (2).jpg: 640x640 (no detections), 14.0ms
# Speed: 4.2ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000018_resized (3).jpg: 640x640 1 white_pawn, 1 black_pawn, 13.6ms
# Speed: 4.3ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.68
# Detected confidence: 0.65
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000018_resized (4).jpg: 640x640 (no detections), 12.1ms
# Speed: 4.4ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000018_resized (5).jpg: 640x640 (no detections), 14.7ms
# Speed: 3.8ms preprocess, 14.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000018_resized.jpg: 640x640 (no detections), 13.3ms
# Speed: 4.4ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000019_resized (2).jpg: 640x640 (no detections), 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000019_resized (3).jpg: 640x640 (no detections), 16.0ms
# Speed: 4.4ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000019_resized.jpg: 640x640 (no detections), 15.4ms
# Speed: 3.1ms preprocess, 15.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000020_resized (2).jpg: 640x640 (no detections), 9.2ms
# Speed: 3.3ms preprocess, 9.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000020_resized.jpg: 640x640 1 black_pawn, 10.1ms
# Speed: 3.3ms preprocess, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.71
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000021_resized (2).jpg: 640x640 (no detections), 17.9ms
# Speed: 5.4ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000021_resized.jpg: 640x640 (no detections), 14.9ms
# Speed: 4.5ms preprocess, 14.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000022_resized (2).jpg: 640x640 (no detections), 15.4ms
# Speed: 4.7ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000022_resized (3).jpg: 640x640 (no detections), 41.4ms
# Speed: 6.1ms preprocess, 41.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000022_resized (4).jpg: 640x640 (no detections), 28.9ms
# Speed: 5.6ms preprocess, 28.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000022_resized.jpg: 640x640 1 black_pawn, 17.2ms
# Speed: 5.5ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.85
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000023_resized (2).jpg: 640x640 (no detections), 15.5ms
# Speed: 4.6ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000023_resized (3).jpg: 640x640 (no detections), 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000023_resized (4).jpg: 640x640 (no detections), 13.3ms
# Speed: 4.5ms preprocess, 13.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000023_resized.jpg: 640x640 1 black_pawn, 14.7ms
# Speed: 4.4ms preprocess, 14.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.85
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000024_resized (2).jpg: 640x640 (no detections), 15.8ms
# Speed: 4.6ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000024_resized (3).jpg: 640x640 (no detections), 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000024_resized.jpg: 640x640 (no detections), 15.0ms
# Speed: 4.9ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000025_resized (2).jpg: 640x640 (no detections), 15.0ms
# Speed: 4.9ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000025_resized (3).jpg: 640x640 (no detections), 20.6ms
# Speed: 5.7ms preprocess, 20.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000025_resized (4).jpg: 640x640 1 black_pawn, 16.4ms
# Speed: 5.5ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.61
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000025_resized.jpg: 640x640 1 black_pawn, 33.8ms
# Speed: 6.3ms preprocess, 33.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.66
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000026_resized (2).jpg: 640x640 (no detections), 14.6ms
# Speed: 4.6ms preprocess, 14.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000026_resized (3).jpg: 640x640 (no detections), 15.6ms
# Speed: 4.8ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000026_resized (4).jpg: 640x640 (no detections), 15.8ms
# Speed: 6.4ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000026_resized.jpg: 640x640 1 black_pawn, 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.85
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000027_resized (2).jpg: 640x640 (no detections), 18.4ms
# Speed: 5.2ms preprocess, 18.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000027_resized (3).jpg: 640x640 1 black_pawn, 15.1ms
# Speed: 5.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.70
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000027_resized (4).jpg: 640x640 (no detections), 14.6ms
# Speed: 4.5ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000027_resized (5).jpg: 640x640 1 black_pawn, 15.0ms
# Speed: 4.4ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.66
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000027_resized.jpg: 640x640 (no detections), 13.9ms
# Speed: 4.3ms preprocess, 13.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000028_resized (2).jpg: 640x640 (no detections), 14.3ms
# Speed: 4.2ms preprocess, 14.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000028_resized (3).jpg: 640x640 (no detections), 14.2ms
# Speed: 4.8ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000028_resized (4).jpg: 640x640 1 black_pawn, 15.5ms
# Speed: 4.6ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.63
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000028_resized.jpg: 640x640 1 white_pawn, 1 black_pawn, 16.0ms
# Speed: 4.7ms preprocess, 16.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.91
# Detected confidence: 0.55
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000029_resized (2).jpg: 640x640 1 white_pawn, 15.6ms
# Speed: 4.9ms preprocess, 15.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.58
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000029_resized (3).jpg: 640x640 1 black_pawn, 15.7ms
# Speed: 4.4ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.75
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000029_resized.jpg: 640x640 (no detections), 17.5ms
# Speed: 4.8ms preprocess, 17.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000030_resized (2).jpg: 640x640 (no detections), 14.0ms
# Speed: 5.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000030_resized (3).jpg: 640x640 (no detections), 15.9ms
# Speed: 4.5ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000030_resized.jpg: 640x640 1 black_pawn, 16.8ms
# Speed: 6.2ms preprocess, 16.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.72
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000031_resized (2).jpg: 640x640 (no detections), 17.1ms
# Speed: 5.0ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000031_resized.jpg: 640x640 1 black_pawn, 21.5ms
# Speed: 5.4ms preprocess, 21.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.60
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000032_resized (2).jpg: 640x640 (no detections), 16.8ms
# Speed: 6.7ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000032_resized (3).jpg: 640x640 (no detections), 31.9ms
# Speed: 5.5ms preprocess, 31.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000032_resized.jpg: 640x640 (no detections), 14.4ms
# Speed: 4.2ms preprocess, 14.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000033_resized.jpg: 640x640 (no detections), 13.5ms
# Speed: 4.2ms preprocess, 13.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000034_resized (2).jpg: 640x640 (no detections), 13.7ms
# Speed: 4.2ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000034_resized (3).jpg: 640x640 1 black_pawn, 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.74
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000034_resized (4).jpg: 640x640 (no detections), 13.4ms
# Speed: 4.0ms preprocess, 13.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000034_resized (5).jpg: 640x640 1 black_pawn, 13.4ms
# Speed: 4.2ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.90
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000034_resized.jpg: 640x640 (no detections), 13.4ms
# Speed: 4.1ms preprocess, 13.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000035_resized (2).jpg: 640x640 (no detections), 13.1ms
# Speed: 4.0ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000035_resized (3).jpg: 640x640 (no detections), 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000035_resized (4).jpg: 640x640 1 black_pawn, 12.4ms
# Speed: 4.1ms preprocess, 12.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.69
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000035_resized.jpg: 640x640 (no detections), 13.0ms
# Speed: 4.0ms preprocess, 13.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000036_resized (2).jpg: 640x640 (no detections), 14.6ms
# Speed: 4.1ms preprocess, 14.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000036_resized.jpg: 640x640 (no detections), 16.3ms
# Speed: 5.2ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000037_resized (2).jpg: 640x640 (no detections), 15.0ms
# Speed: 4.8ms preprocess, 15.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000037_resized (3).jpg: 640x640 1 black_pawn, 15.2ms
# Speed: 5.4ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.68
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000037_resized.jpg: 640x640 (no detections), 15.1ms
# Speed: 4.4ms preprocess, 15.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000038_resized (2).jpg: 640x640 1 black_pawn, 16.3ms
# Speed: 4.6ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.70
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000038_resized.jpg: 640x640 1 white_pawn, 16.8ms
# Speed: 4.8ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.67
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000039_resized (2).jpg: 640x640 (no detections), 15.8ms
# Speed: 4.7ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000039_resized (3).jpg: 640x640 1 black_pawn, 15.2ms
# Speed: 4.5ms preprocess, 15.2ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.60
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000039_resized (4).jpg: 640x640 (no detections), 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000039_resized (5).jpg: 640x640 1 black_pawn, 27.9ms
# Speed: 4.8ms preprocess, 27.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.50
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000039_resized.jpg: 640x640 (no detections), 13.3ms
# Speed: 3.9ms preprocess, 13.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000040_resized.jpg: 640x640 (no detections), 12.4ms
# Speed: 3.9ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000041_resized (2).jpg: 640x640 1 black_pawn, 13.9ms
# Speed: 4.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.88
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000041_resized.jpg: 640x640 1 black_pawn, 16.6ms
# Speed: 4.9ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.64
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000042_resized (2).jpg: 640x640 (no detections), 29.8ms
# Speed: 4.2ms preprocess, 29.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000042_resized (3).jpg: 640x640 (no detections), 16.7ms
# Speed: 4.9ms preprocess, 16.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000042_resized.jpg: 640x640 (no detections), 16.3ms
# Speed: 5.5ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000043_resized (2).jpg: 640x640 (no detections), 15.5ms
# Speed: 4.8ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000043_resized (3).jpg: 640x640 1 black_pawn, 15.3ms
# Speed: 4.6ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.86
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000043_resized (4).jpg: 640x640 (no detections), 15.7ms
# Speed: 4.5ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000043_resized (5).jpg: 640x640 1 black_pawn, 26.4ms
# Speed: 4.3ms preprocess, 26.4ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.80
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000043_resized.jpg: 640x640 1 black_pawn, 26.7ms
# Speed: 5.0ms preprocess, 26.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.77
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000044_resized (2).jpg: 640x640 (no detections), 17.5ms
# Speed: 5.1ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000044_resized (3).jpg: 640x640 (no detections), 18.9ms
# Speed: 5.5ms preprocess, 18.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000044_resized (4).jpg: 640x640 (no detections), 26.9ms
# Speed: 6.0ms preprocess, 26.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000044_resized.jpg: 640x640 (no detections), 14.5ms
# Speed: 4.6ms preprocess, 14.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000045_resized (2).jpg: 640x640 (no detections), 13.7ms
# Speed: 4.2ms preprocess, 13.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000045_resized (3).jpg: 640x640 (no detections), 14.2ms
# Speed: 4.1ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000045_resized.jpg: 640x640 1 black_pawn, 15.1ms
# Speed: 5.1ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.54
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000046_resized (2).jpg: 640x640 (no detections), 18.3ms
# Speed: 4.9ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000046_resized (3).jpg: 640x640 1 black_pawn, 16.3ms
# Speed: 5.3ms preprocess, 16.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.67
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000046_resized.jpg: 640x640 (no detections), 32.3ms
# Speed: 5.8ms preprocess, 32.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000047_resized (2).jpg: 640x640 1 black_pawn, 20.2ms
# Speed: 5.0ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.91
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000047_resized (3).jpg: 640x640 (no detections), 14.8ms
# Speed: 4.6ms preprocess, 14.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000047_resized.jpg: 640x640 (no detections), 14.4ms
# Speed: 4.5ms preprocess, 14.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000048_resized (2).jpg: 640x640 (no detections), 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000048_resized.jpg: 640x640 (no detections), 13.4ms
# Speed: 4.6ms preprocess, 13.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000049_resized.jpg: 640x640 (no detections), 13.5ms
# Speed: 4.1ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000050_resized (2).jpg: 640x640 (no detections), 13.3ms
# Speed: 4.0ms preprocess, 13.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000050_resized (3).jpg: 640x640 (no detections), 13.1ms
# Speed: 4.1ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000050_resized (4).jpg: 640x640 1 black_pawn, 13.0ms
# Speed: 3.9ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.84
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000050_resized.jpg: 640x640 (no detections), 15.9ms
# Speed: 4.0ms preprocess, 15.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000051_resized (2).jpg: 640x640 (no detections), 13.4ms
# Speed: 4.2ms preprocess, 13.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000051_resized.jpg: 640x640 (no detections), 13.5ms
# Speed: 4.4ms preprocess, 13.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000052_resized (2).jpg: 640x640 (no detections), 13.6ms
# Speed: 4.5ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000052_resized (3).jpg: 640x640 (no detections), 15.0ms
# Speed: 4.1ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000052_resized (4).jpg: 640x640 1 black_pawn, 14.8ms
# Speed: 4.8ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.57
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000052_resized (5).jpg: 640x640 (no detections), 30.6ms
# Speed: 5.3ms preprocess, 30.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000052_resized.jpg: 640x640 1 black_pawn, 13.6ms
# Speed: 4.3ms preprocess, 13.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.53
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000053_resized (2).jpg: 640x640 1 black_pawn, 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.50
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000053_resized (3).jpg: 640x640 (no detections), 24.6ms
# Speed: 4.4ms preprocess, 24.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000053_resized.jpg: 640x640 (no detections), 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000054_resized (2).jpg: 640x640 (no detections), 12.6ms
# Speed: 4.1ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000054_resized (3).jpg: 640x640 (no detections), 13.5ms
# Speed: 4.5ms preprocess, 13.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000054_resized (4).jpg: 640x640 (no detections), 13.4ms
# Speed: 4.0ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000054_resized.jpg: 640x640 (no detections), 12.8ms
# Speed: 4.1ms preprocess, 12.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000055_resized (2).jpg: 640x640 (no detections), 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000055_resized.jpg: 640x640 (no detections), 13.5ms
# Speed: 4.4ms preprocess, 13.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000056_resized.jpg: 640x640 (no detections), 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000057_resized (2).jpg: 640x640 1 black_pawn, 13.2ms
# Speed: 4.1ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.53
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000057_resized (3).jpg: 640x640 1 black_pawn, 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.73
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000057_resized.jpg: 640x640 (no detections), 18.7ms
# Speed: 4.1ms preprocess, 18.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000058_resized (2).jpg: 640x640 (no detections), 13.7ms
# Speed: 4.3ms preprocess, 13.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000058_resized.jpg: 640x640 1 white_pawn, 14.6ms
# Speed: 4.4ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.59
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000059_resized (2).jpg: 640x640 (no detections), 13.7ms
# Speed: 4.0ms preprocess, 13.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000059_resized (3).jpg: 640x640 (no detections), 23.1ms
# Speed: 4.1ms preprocess, 23.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
# Speed: 4.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000255_resized.jpg: 640x640 (no detections), 13.1ms
# Speed: 4.2ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000257_resized (2).jpg: 640x640 (no detections), 14.8ms
# Speed: 4.2ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000257_resized.jpg: 640x640 (no detections), 15.0ms
# Speed: 4.4ms preprocess, 15.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000258_resized (2).jpg: 640x640 (no detections), 14.6ms
# Speed: 4.7ms preprocess, 14.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000258_resized (3).jpg: 640x640 (no detections), 14.4ms
# Speed: 4.4ms preprocess, 14.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000258_resized (4).jpg: 640x640 (no detections), 29.1ms
# Speed: 5.3ms preprocess, 29.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000258_resized.jpg: 640x640 (no detections), 14.4ms
# Speed: 4.6ms preprocess, 14.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000261_resized.jpg: 640x640 1 black_pawn, 16.1ms
# Speed: 4.4ms preprocess, 16.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.59
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000262_resized.jpg: 640x640 (no detections), 14.9ms
# Speed: 4.9ms preprocess, 14.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000263_resized (2).jpg: 640x640 (no detections), 15.3ms
# Speed: 4.7ms preprocess, 15.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000263_resized.jpg: 640x640 1 black_pawn, 13.6ms
# Speed: 4.5ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.74
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000264_resized (2).jpg: 640x640 (no detections), 15.1ms
# Speed: 4.7ms preprocess, 15.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000264_resized.jpg: 640x640 (no detections), 13.6ms
# Speed: 4.5ms preprocess, 13.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000265_resized (2).jpg: 640x640 (no detections), 14.2ms
# Speed: 4.5ms preprocess, 14.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000265_resized (3).jpg: 640x640 (no detections), 14.1ms
# Speed: 4.5ms preprocess, 14.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000265_resized.jpg: 640x640 (no detections), 13.0ms
# Speed: 4.4ms preprocess, 13.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000266_resized.jpg: 640x640 (no detections), 13.4ms
# Speed: 4.4ms preprocess, 13.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000267_resized (2).jpg: 640x640 1 black_pawn, 13.7ms
# Speed: 4.7ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.64
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000267_resized.jpg: 640x640 (no detections), 13.7ms
# Speed: 4.3ms preprocess, 13.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000269_resized.jpg: 640x640 (no detections), 14.0ms
# Speed: 5.0ms preprocess, 14.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000271_resized.jpg: 640x640 (no detections), 13.7ms
# Speed: 4.3ms preprocess, 13.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000272_resized (2).jpg: 640x640 (no detections), 15.0ms
# Speed: 4.4ms preprocess, 15.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000272_resized.jpg: 640x640 (no detections), 14.1ms
# Speed: 4.4ms preprocess, 14.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000275_resized.jpg: 640x640 (no detections), 21.1ms
# Speed: 5.1ms preprocess, 21.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000276_resized (2).jpg: 640x640 (no detections), 13.1ms
# Speed: 4.2ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000276_resized.jpg: 640x640 1 black_pawn, 14.1ms
# Speed: 4.2ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.76
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000278_resized.jpg: 640x640 (no detections), 13.1ms
# Speed: 4.4ms preprocess, 13.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000280_resized (2).jpg: 640x640 (no detections), 13.0ms
# Speed: 4.2ms preprocess, 13.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000280_resized.jpg: 640x640 (no detections), 13.6ms
# Speed: 4.4ms preprocess, 13.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000284_resized (2).jpg: 640x640 (no detections), 13.0ms
# Speed: 4.3ms preprocess, 13.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000284_resized.jpg: 640x640 (no detections), 12.9ms
# Speed: 4.1ms preprocess, 12.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000285_resized (2).jpg: 640x640 1 black_pawn, 13.0ms
# Speed: 4.3ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.51
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000285_resized.jpg: 640x640 1 white_pawn, 12.5ms
# Speed: 4.7ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.67
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000286_resized.jpg: 640x640 (no detections), 12.0ms
# Speed: 4.1ms preprocess, 12.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000287_resized.jpg: 640x640 (no detections), 12.2ms
# Speed: 4.0ms preprocess, 12.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000289_resized.jpg: 640x640 (no detections), 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000292_resized.jpg: 640x640 (no detections), 12.1ms
# Speed: 3.9ms preprocess, 12.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000294_resized.jpg: 640x640 (no detections), 12.8ms
# Speed: 4.0ms preprocess, 12.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000295_resized (2).jpg: 640x640 1 black_pawn, 14.8ms
# Speed: 4.3ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.59
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000295_resized.jpg: 640x640 (no detections), 12.6ms
# Speed: 4.5ms preprocess, 12.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000297_resized.jpg: 640x640 (no detections), 26.0ms
# Speed: 4.5ms preprocess, 26.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000299_resized.jpg: 640x640 (no detections), 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000300_resized.jpg: 640x640 (no detections), 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000301_resized.jpg: 640x640 (no detections), 13.4ms
# Speed: 4.2ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000302_resized.jpg: 640x640 (no detections), 13.1ms
# Speed: 4.2ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000308_resized.jpg: 640x640 (no detections), 13.6ms
# Speed: 4.4ms preprocess, 13.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000310_resized.jpg: 640x640 (no detections), 13.2ms
# Speed: 4.2ms preprocess, 13.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000314_resized.jpg: 640x640 (no detections), 13.3ms
# Speed: 4.1ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000320_resized.jpg: 640x640 (no detections), 13.1ms
# Speed: 4.3ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000322_resized.jpg: 640x640 (no detections), 13.2ms
# Speed: 4.2ms preprocess, 13.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000326_resized.jpg: 640x640 1 black_pawn, 18.2ms
# Speed: 6.0ms preprocess, 18.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.74
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000328_resized.jpg: 640x640 (no detections), 15.2ms
# Speed: 4.5ms preprocess, 15.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000330_resized.jpg: 640x640 1 black_pawn, 23.8ms
# Speed: 5.4ms preprocess, 23.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.74
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000332_resized.jpg: 640x640 (no detections), 13.2ms
# Speed: 4.5ms preprocess, 13.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000333_resized.jpg: 640x640 (no detections), 14.0ms
# Speed: 4.3ms preprocess, 14.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000336_resized.jpg: 640x640 (no detections), 13.3ms
# Speed: 4.4ms preprocess, 13.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000341_resized.jpg: 640x640 (no detections), 12.6ms
# Speed: 4.5ms preprocess, 12.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000343_resized.jpg: 640x640 1 black_pawn, 12.1ms
# Speed: 4.8ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.51
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000345_resized.jpg: 640x640 (no detections), 12.7ms
# Speed: 3.9ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000349_resized.jpg: 640x640 (no detections), 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000354_resized.jpg: 640x640 (no detections), 24.9ms
# Speed: 4.5ms preprocess, 24.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000365_resized.jpg: 640x640 1 black_pawn, 12.1ms
# Speed: 3.9ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.54
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000368_resized.jpg: 640x640 (no detections), 14.4ms
# Speed: 4.3ms preprocess, 14.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000381_resized.jpg: 640x640 1 black_pawn, 14.0ms
# Speed: 4.4ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Detected confidence: 0.67
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000385_resized.jpg: 640x640 (no detections), 13.2ms
# Speed: 4.2ms preprocess, 13.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000387_resized.jpg: 640x640 (no detections), 13.7ms
# Speed: 4.4ms preprocess, 13.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000391_resized.jpg: 640x640 (no detections), 12.8ms
# Speed: 4.3ms preprocess, 12.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\lewka\Downloads\image_to_test_label\image_to_test_label\00000395_resized.jpg: 640x640 (no detections), 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
